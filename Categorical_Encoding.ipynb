# %% [markdown]
# <a href="https://colab.research.google.com/github/nikita1995dadhich-dev/api-ethics-assignment/blob/main/Categorical_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1 — Categorical Encoding

# %%
import pandas as pd

data = {
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
    'City': ['Mumbai', 'Delhi', 'Chennai', 'Mumbai', 'Delhi'],
    'Size': ['Small', 'Large', 'Medium', 'Large', 'Small'],
    'Age': [25, 45, 32, 60, 28],
    'Fare': [15, 300, 85, 450, 20]
}

df = pd.DataFrame(data)

# -------- Gender: Label Encoding --------
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})

# -------- Size: Ordered Label Encoding --------
df['Size'] = df['Size'].map({'Small': 0, 'Medium': 1, 'Large': 2})

# -------- City: One-Hot Encoding (drop first to avoid dummy trap) --------
df = pd.get_dummies(df, columns=['City'], drop_first=True)

print(df)
# Out:
#    Gender  Size  Age  Fare  City_Delhi  City_Mumbai
# 0       1     0   25    15       False         True
# 1       0     2   45   300        True        False
# 2       0     1   32    85       False        False
# 3       1     2   60   450       False         True
# 4       0     0   28    20        True        False

# %% [markdown]
# Task 2 — Feature Scaling
# # RobustScaler is used because the Fare column contains an outlier (450).
# # Unlike StandardScaler or MinMaxScaler, RobustScaler uses median and IQR,
# # making it less sensitive to extreme values and more suitable for this dataset.

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

print(df)
# Out:
#    Gender  Size       Age      Fare  City_Delhi  City_Mumbai
# 0       1     0 -0.411765 -0.250000       False         True
# 1       0     2  0.764706  0.767857        True        False
# 2       0     1  0.000000  0.000000       False        False
# 3       1     2  1.647059  1.303571       False         True
# 4       0     0 -0.235294 -0.232143        True        False
